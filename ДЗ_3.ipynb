# %%
# !wget https://raw.githubusercontent.com/Ladalisovaya/guacamole/refs/heads/main/The%20Picture%20of%20Dorian%20Gray2.txt
# Out:
# --2024-11-26 20:08:51--  https://raw.githubusercontent.com/Ladalisovaya/guacamole/refs/heads/main/The%20Picture%20of%20Dorian%20Gray2.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 445938 (435K) [text/plain]
# Saving to: ‘The Picture of Dorian Gray2.txt’
#
# The Picture of Dori 100%[===================>] 435.49K  --.-KB/s    in 0.05s
#
# 2024-11-26 20:08:52 (9.22 MB/s) - ‘The Picture of Dorian Gray2.txt’ saved [445938/445938]

# %%
from gensim.utils import simple_preprocess
from gensim.models import Word2Vec

# %%
with open("The Picture of Dorian Gray2.txt", "r", encoding="utf-8") as f:
    text = f.read()

# %%
sentences = [simple_preprocess(sentence) for sentence in text.splitlines() if sentence]

# %%
model = Word2Vec(sentences, vector_size=100, window=5, min_count=2, workers=4)

# %%
model.wv.most_similar("dorian", topn=5)
# Out:
# [('mr', 0.9994529485702515),
#  ('answered', 0.9980167150497437),
#  ('cried', 0.9979800581932068),
#  ('hallward', 0.9976457357406616),
#  ('looking', 0.9976144433021545)]

# %%
from nltk.corpus import stopwords
import nltk

nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
sentences = [
    [word for word in simple_preprocess(sentence) if word not in stop_words]
    for sentence in text.splitlines() if sentence
]

# %%
model = Word2Vec(sentences, vector_size=100, window=5, min_count=2, workers=4)

# %%
model.wv.most_similar("dorian", topn=5)
# Out:
# [('one', 0.9989927411079407),
#  ('must', 0.9989562630653381),
#  ('would', 0.9989272356033325),
#  ('never', 0.9988576769828796),
#  ('said', 0.9988381862640381)]

# %%
from gensim.corpora.dictionary import Dictionary
from gensim.models import LdaModel

# %%
dictionary = Dictionary(sentences)
corpus = [dictionary.doc2bow(sentence) for sentence in sentences]

# %%
lda_model = LdaModel(corpus, num_topics=5, id2word=dictionary, passes=15)

# %%
topics = lda_model.print_topics(num_words=5)
for idx, topic in topics:
    print(f"Topic {idx}: {topic}")
# Out:
# Topic 0: 0.011*"thing" + 0.010*"man" + 0.009*"going" + 0.009*"something" + 0.007*"upon"
# Topic 1: 0.035*"one" + 0.021*"would" + 0.013*"life" + 0.012*"us" + 0.010*"world"
# Topic 2: 0.013*"quite" + 0.010*"like" + 0.009*"things" + 0.009*"little" + 0.008*"tell"
# Topic 3: 0.012*"one" + 0.009*"would" + 0.008*"like" + 0.007*"life" + 0.007*"portrait"
# Topic 4: 0.039*"dorian" + 0.024*"said" + 0.022*"lord" + 0.021*"henry" + 0.017*"gray"

# %%
# !pip install pyLDAvis
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 23.5 MB/s eta 0:00:00
# ...

# %%
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis

lda_display = gensimvis.prepare(lda_model, corpus, dictionary, sort_topics=False)

pyLDAvis.display(lda_display)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el3181396863777498881416710897" style="background-color:white;"></div>
# <script type="text/javascript">
#
# ...

# %%
pyLDAvis.save_html(lda_display, 'lda_visualization.html')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
